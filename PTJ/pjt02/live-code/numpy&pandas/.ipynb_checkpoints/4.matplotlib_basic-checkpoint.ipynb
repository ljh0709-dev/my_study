# %% [markdown]
# # Matplotlib 기본 사용법 익히기

# %% [markdown]
# ## 목차
#
# 1. [필요 패키지 설치 및 import](#1.-필요-패키지-설치-및-import)
#
# 2. [matplotlib 기본 사용법(라인 그래프 그리기)](#2.-matplotlib-기본-사용법(라인-그래프-그리기))
#
# 3. [두 가지 선 그리기](#3.-두-가지-선-그리기)
#
# 4. [막대 그래프 그리기](#4.-막대-그래프-그리기)
#
# 5. [히스토그램 그리기](#5.-히스토그램-그리기)
#
# 6. [데이터와 함께 활용해보기](#6.-데이터와-함께-활용해보기)
#
# 7. [실무에서 자주 쓰는 Matplotlib](#7.-실무에서-자주-쓰는-Matplotlib)
#     - 7.1 [subplots - 여러 그래프 배치](#7.1-subplots)
#     - 7.2 [scatter, boxplot](#7.2-scatter-boxplot)
#     - 7.3 [savefig, tight_layout](#7.3-savefig-tight_layout)

# %% [markdown]
# ## 1. 필요 패키지 설치 및 import

# %%
# !pip install matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. matplotlib 기본 사용법(라인 그래프 그리기)

# %%
import matplotlib.pyplot as plt

# 데이터 생성
x = [1, 2, 3, 4, 5]  # x 좌표값
y = [2, 4, 6, 8, 10]  # y 좌표값

# 그래프 그리기
plt.plot(x, y)

# 그래프에 제목과 축 레이블 추가
plt.title('Simple Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 그래프 표시
plt.show()

# %% [markdown]
# ## 3. 두 가지 선 그리기

# %%
# 데이터 생성
x = [1, 2, 3, 4, 5]  # x 좌표값
y = [2, 4, 6, 8, 10]  # y 좌표값
y2 = [3, 6, 9, 12, 15] # y2 좌표값

# 그래프 그리기
plt.plot(x, y, label='y')
plt.plot(x, y2, label='y2')

# 범례 추가
plt.legend()

# 그래프에 제목과 축 레이블 추가
plt.title('Simple Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 그래프 표시
plt.show()

# %% [markdown]
# ## 4. 막대 그래프 그리기
# - 범주형 데이터를 시각화하기 위해 사용되며, 주로 범주 간의 비교를 위해 사용됨
# - 각 막대는 독립적이며, 막대 간의 간격이 존재합니다.
# - ex) 다양한 제품의 판매량 비교

# %%
import matplotlib.pyplot as plt

# 데이터 생성
x = ['A', 'B', 'C', 'D', 'E']  # 카테고리
y = [3, 7, 2, 5, 9]  # 값

# 그래프 그리기
plt.bar(x, y)

# 그래프에 제목과 축 레이블 추가
plt.title('Bar Plot')
plt.xlabel('Category')
plt.ylabel('Value')

# 그래프 표시
plt.show()

# %% [markdown]
# ## 5. 히스토그램 그리기
# - 연속된 데이터의 분포를 시각화하기 위해 사용됨
# - 데이터를 구간으로 나누고, 각 구간에 속하는 데이터의 빈도수 또는 밀도를 나타냄
# - ex) 시험 점수의 분포, 연령대에 따른 인구 분포 등

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성 (NumPy 2.x 권장: Generator API)
rng = np.random.default_rng()
data = rng.standard_normal(1000)  # 표준정규분포 랜덤 데이터

# 그래프 그리기
plt.hist(data, bins=30)

# 그래프에 제목과 축 레이블 추가
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')

# 그래프 표시
plt.show()

# %% [markdown]
# ## 6. 데이터와 함께 활용해보기

# %% [markdown]
# - csv 파일을 읽어와 Pandas DataFrame 생성하기

# %%
# Numpy 를 활용한 csv file open
def file_open_by_numpy():
    # np.loadtxt(구분자 = ',', 데이터 타입: string)
    np_arr = np.loadtxt('data/test_data.CSV', delimiter=",", encoding='cp949', dtype=str)
    return np_arr

arr = file_open_by_numpy()

# 첫 번째 열을 헤더로 하는 데이터 프레임 생성
header = arr[0, :]  # 첫 번째 행을 헤더로 사용
data = arr[1:, :]  # 첫 번째 행을 제외한 나머지 데이터

df = pd.DataFrame(data, columns=header)
df.head()
# Out:
#     이름  나이 성별   직업    사는곳
# 0  김현우  25  남   교수   경상남도
# 1  이태현  28  여   군인   경상북도
# 2  박현준  36  남   기자  서울/경기
# 3  최성민  34  남  리포터    강원도
# 4  정준우  45  남   모델    강원도

# %%
df.dtypes
# Out:
# 이름     str
# 나이     str
# 성별     str
# 직업     str
# 사는곳    str
# dtype: object

# %% [markdown]
# ---
#
# ## 7. 실무에서 자주 쓰는 Matplotlib
#
# **subplots**, **scatter** / **boxplot**, **savefig**, **tight_layout** 등 실무에서 자주 사용하는 요소를 정리합니다.

# %% [markdown]
# ### 7.1 subplots — 여러 그래프 배치
#
# - `fig, axes = plt.subplots(행, 열)` 로 한 Figure 안에 여러 Axes를 만들고, `axes[i,j]`에 그립니다.
# - **아래 코드:** 2×2 서브플롯에 선 그래프, 막대, 히스토그램, 산점수를 그린 뒤 `tight_layout()` 으로 겹침을 줄이고 `show()` 합니다.

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 6))
axes[0, 0].plot([1, 2, 3], [1, 4, 9])
axes[0, 0].set_title('Line')
axes[0, 1].bar(['A', 'B', 'C'], [3, 7, 2])
axes[0, 1].set_title('Bar')
rng = np.random.default_rng(42)
axes[1, 0].hist(rng.standard_normal(200), bins=15)
axes[1, 0].set_title('Hist')
axes[1, 1].scatter([1,2,3,4,5], [2,4,1,5,3])
axes[1, 1].set_title('Scatter')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.2 scatter, boxplot
#
# - **scatter**: 두 변수 관계(상관·분포) 확인
# - **boxplot**: 연속형 변수의 사분위·이상치 확인
# - **아래 코드:** `test_data` 에서 나이 결측 제거 후, 왼쪽에 나이 scatter, 오른쪽에 나이 boxplot을 1×2 서브플롯으로 그립니다.

# %%
df = pd.read_csv('data/test_data.CSV', encoding='cp949')
df['나이'] = pd.to_numeric(df['나이'], errors='coerce')
df_na = df.dropna(subset=['나이'])
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
ax1.scatter(range(len(df_na)), df_na['나이'], alpha=0.6)
ax1.set_title('나이 scatter')
ax2.boxplot(df_na['나이'])
ax2.set_title('나이 boxplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_14332\44244968.py:9: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_14332\44244968.py:9: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\SSAFY\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SSAFY\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 나이 필드를 숫자 형식으로 변환 (int64 명시, pandas 2.x 호환)
df['나이'] = df['나이'].astype('int64')

# 나이에 대한 히스토그램 출력
df['나이'].plot(kind='hist', bins=10)

# 그래프 제목 설정
plt.title('Age Distribution')

# x축 레이블 설정
plt.xlabel('Age')

# y축 레이블 설정
plt.ylabel('Count')

# 그래프 출력
plt.show()

# %% [markdown]
# ### 7.3 savefig, tight_layout
#
# - `plt.savefig(경로, dpi=..., bbox_inches='tight')` 로 그래프를 파일로 저장합니다. `dpi`로 해상도, `bbox_inches='tight'`로 여백을 줄입니다.
# - `plt.tight_layout()` 은 서브플롯 겹침을 줄일 때 그리기 후·저장 전에 호출합니다.
# - **아래 코드:** 간단한 선 그래프를 그린 뒤 `data/plot_example.png` 로 저장합니다.

# %%
plt.figure(figsize=(5, 3))
plt.plot([1, 2, 3], [1, 4, 9])
plt.title('Save Example')
plt.tight_layout()
plt.savefig('data/plot_example.png', dpi=150, bbox_inches='tight')
plt.show()
# data/plot_example.png 파일이 생성됨
